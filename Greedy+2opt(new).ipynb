# %%
import time
import copy
import math
import csv  

def read_path_from_csv(filename):
    path = []
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # 跳过标题行
        for row in reader:
            x, y = float(row[0]), float(row[1])
            path.append((x, y))
    return path

def greedy_path(points):  #最近邻生成初始路线
    
    unvisited = points[:]
    path = [unvisited.pop(0)]              # 从第 1 个点出发
    while unvisited:
        last = path[-1]
        nearest = min(unvisited, key=lambda p: calculate_distance(last, p))   #在 unvisited 这个列表中，找出一个点 p，使得 calculate_distance(last, p) 最小。
        unvisited.remove(nearest)
        path.append(nearest)
    return path
    
# 利用勾股定理计算两个点之间的距离
def calculate_distance(point1, point2):
    (x1, y1) = point1
    (x2, y2) = point2
    distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    return distance


# 计算总距离
def calculate_total_distance(path):
    total_distance = 0
    n = len(path)
    for i in range(n):
        total_distance += calculate_distance(path[i], path[(i + 1) % n]) #%n是wei l回到起点
    return round(total_distance, 2)


file_list = [f'input_{k}.csv' for k in range(7)]    # 新增
if __name__ == '__main__':
    for fname in file_list:                 # 新增
        start_time = time.time()            # 记录当前文件的开始时间
    
        improved = True                     # 每个文件重新初始化
        old_path = read_path_from_csv(fname)
        old_path = greedy_path(old_path) 
        new_path = copy.deepcopy(old_path)


        while improved:
            improved = False
            new_path = copy.deepcopy(old_path) 
            for i in range(1, len(new_path)):
                for j in range(i + 1, len(new_path) + 1):  # 注意到 len+1 是为了允许跨越结尾
                    if j <= len(new_path):    # 正常情况（不跨越首尾）
                        
                        segment = new_path[i:j]
                        reversed_segment = list(reversed(segment))
                        candidate = new_path[:i] + reversed_segment + new_path[j:]
                    else:       # 🔄 跨越首尾情况：例如 i = 3, j = 7（n=6）
                        
                        j_mod = j % len(new_path)
                        segment = new_path[i:] + new_path[:j_mod]
                        reversed_segment = list(reversed(segment))
                        candidate = reversed_segment[-j_mod:] + new_path[j_mod:i] + reversed_segment[:-j_mod]
            
                    # 替代原来的判断逻辑
                    if calculate_total_distance(old_path) > calculate_total_distance(candidate):
                        old_path = copy.deepcopy(candidate)
                        improved = True
                        break
                if improved:
                    break


    # 打印结果
        print("\n文件:", fname)
        #print("2-opt算法:", old_path)
        print("总距离：", calculate_total_distance(old_path))
        print("总耗时：", time.time() - start_time)
# Out:
# 文件: input_0.csv
# 总距离： 3418.1
# 总耗时： 0.0009808540344238281
#
# 文件: input_1.csv
# 总距离： 3832.29
# 总耗时： 0.0006999969482421875
#
# 文件: input_2.csv
# 总距离： 4994.89
# 总耗时： 0.0049190521240234375
#
# 文件: input_3.csv
# 总距离： 9195.78
# 总耗时： 0.6739499568939209
#
# 文件: input_4.csv
# 总距离： 11338.42
# 总耗时： 6.276160955429077
#
# 文件: input_5.csv
# 总距离： 21039.95
# 总耗时： 2405.115653991699
